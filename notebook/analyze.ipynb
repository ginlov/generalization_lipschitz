# %%
import numpy as np

# %%
with open('../svc1.txt') as f:
    lines = f.readlines()

# %%
# Out:
# ['Train loss 1.3884400129318237\n',
#  "Rob ['2.0+-0.0', '2.0+-0.0', '2.0+-0.0', '2.0+-0.0']\n",
#  "LocalRob ['1.9997040033340454+-4.9484924602438696e-08', '1.9868600368499756+-2.2095289295975817e-06', '1.9184077978134155+-8.742265890759882e-06', '1.845080018043518+-0.0']\n",
#  "localsen ['0.7708849906921387+-2.3254660845850594e-05', '0.7459315061569214+-8.329680895258207e-06', '0.7180553078651428+-1.4658528016298078e-05', '0.6992400288581848+-0.0']\n",
#  "Localavg ['1.4094407558441162+-9.0643306194238e-09', '1.408587098121643+-1.991431872738758e-07', '1.4043875932693481+-6.155347023195645e-07', '1.3982189893722534+-0.0']"]

# %%
def process_data(file_name):
    with open(file_name) as f:
        data = f.readlines()
    train_loss = data[0].strip().split(' ')[-1]
    rob = eval(data[1].strip().split(' ', 1)[1])
    local_rob = eval(data[2].strip().split(' ', 1)[1])
    localsen = eval(data[3].strip().split(' ', 1)[1])
    localavg = eval(data[4].strip().split(' ', 1)[1])
    return train_loss, rob, local_rob, localsen, localavg

# %%
extracted_data = process_data('../svc1.txt')

# %%
extracted_data
# Out:
# ('1.3884400129318237',
#  ['2.0+-0.0', '2.0+-0.0', '2.0+-0.0', '2.0+-0.0'],
#  ['1.9997040033340454+-4.9484924602438696e-08',
#   '1.9868600368499756+-2.2095289295975817e-06',
#   '1.9184077978134155+-8.742265890759882e-06',
#   '1.845080018043518+-0.0'],
#  ['0.7708849906921387+-2.3254660845850594e-05',
#   '0.7459315061569214+-8.329680895258207e-06',
#   '0.7180553078651428+-1.4658528016298078e-05',
#   '0.6992400288581848+-0.0'],
#  ['1.4094407558441162+-9.0643306194238e-09',
#   '1.408587098121643+-1.991431872738758e-07',
#   '1.4043875932693481+-6.155347023195645e-07',
#   '1.3982189893722534+-0.0'])

# %%
import os

def convert_to_float(text):
    mean_str, variance_str = text.split('+-')
    mean = float(mean_str)
    variance = float(variance_str)
    return mean, variance

def extract_data_from_file(filepath):
    with open(filepath, 'r') as file:
        data = file.readlines()
    
    train_loss = data[0].strip().split(' ')[-1]
    rob = eval(data[1].strip().split(' ', 1)[1])
    local_rob = eval(data[2].strip().split(' ', 1)[1])
    localsen = eval(data[3].strip().split(' ', 1)[1])
    localavg = eval(data[4].strip().split(' ', 1)[1])
    
    return train_loss, rob, local_rob, localsen, localavg

def generate_latex_table(data_dict):
    latex_table = f"""
    \\begin{{table}}[tp]
    \\tiny
    \\centering
    \\caption{{Estimates for the true errors of different models trained on CIFAR10 dataset, when the size $K$ of the partition $\\Gamma$ varies.}}
    \\begin{{tabular}}{{|c|c|c|c|c|c|c|}}
    \\hline
    \\multirow{{2}}{{*}}{{\\textbf{{Model}}}} & \\multirow{{2}}{{*}}{{\\textbf{{Valid Acc}}}} & \\multirow{{2}}{{*}}{{\\textbf{{K}}}} & \\multirow{{2}}{{*}}{{\\textbf{{Rob}}}} & \\multirow{{2}}{{*}}{{\\textbf{{LocalRob}}}} & \\multirow{{2}}{{*}}{{\\textbf{{LocalSen}}}} & \\multirow{{2}}{{*}}{{\\textbf{{LocalAvg}}}} \\\\
    & & & & & &\\\\
    \\hline \\hline
    """
    
    for model, data in data_dict.items():
        for i in range(4):
            rob_mean, rob_var = convert_to_float(data['rob'][i])
            local_rob_mean, local_rob_var = convert_to_float(data['local_rob'][i])
            localsen_mean, localsen_var = convert_to_float(data['localsen'][i])
            localavg_mean, localavg_var = convert_to_float(data['localavg'][i])
            
            latex_table += f"""
            \\multirow{{4}}{{*}}{{{model}}} & \\multirow{{4}}{{*}}{{{data['train_loss']}}}  
                    & {100 * (i + 1)} & {rob_mean:.2f} $\\pm$ {rob_var:.2e} & {local_rob_mean:.2f} $\\pm$ {local_rob_var:.2e} & {localsen_mean:.2f} $\\pm$ {localsen_var:.2e} & {localavg_mean:.2f} $\\pm$ {localavg_var:.2e} \\\\
            """
    
    latex_table += """
    \\hline
    \\end{tabular}
    \\caption{Results}
    \\label{tab:results}
    \\end{table}
    """
    
    return latex_table

# Directory containing the files
directory = '/home/leo/Code/generalization_lipschitz/'

# Dictionary to store the extracted data
data_dict = {}

# Extract data from each file
for filename in os.listdir(directory):
    if filename.endswith('.txt'):
        model_name = filename.split('.')[0]
        filepath = os.path.join(directory, filename)
        train_loss, rob, local_rob, localsen, localavg = extract_data_from_file(filepath)
        data_dict[model_name] = {
            'train_loss': train_loss,
            'rob': rob,
            'local_rob': local_rob,
            'localsen': localsen,
            'localavg': localavg
        }

# Generate the LaTeX table
latex_table = generate_latex_table(data_dict)
print(latex_table)
# Out:
#     \begin{table}[tp]
#     \tiny
#     \centering
#     \caption{Estimates for the true errors of different models trained on CIFAR10 dataset, when the size $K$ of the partition $\Gamma$ varies.}
#     \begin{tabular}{|c|c|c|c|c|c|c|}
#     \hline
#     \multirow{2}{*}{\textbf{Model}} & \multirow{2}{*}{\textbf{Valid Acc}} & \multirow{2}{*}{\textbf{K}} & \multirow{2}{*}{\textbf{Rob}} & \multirow{2}{*}{\textbf{LocalRob}} & \multirow{2}{*}{\textbf{LocalSen}} & \multirow{2}{*}{\textbf{LocalAvg}} \\
#     & & & & & &\\
#     \hline \hline
#
#             \multirow{4}{*}{svhn_adaboost4} & \multirow{4}{*}{1.6216061115264893}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 1.27e-06 & 0.60 $\pm$ 4.78e-05 & 1.62 $\pm$ 2.22e-06 \\
#
#             \multirow{4}{*}{svhn_adaboost4} & \multirow{4}{*}{1.6216061115264893}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 1.96 $\pm$ 3.69e-05 & 0.56 $\pm$ 4.24e-05 & 1.62 $\pm$ 1.11e-06 \\
#
#             \multirow{4}{*}{svhn_adaboost4} & \multirow{4}{*}{1.6216061115264893}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.79 $\pm$ 1.68e-04 & 0.51 $\pm$ 4.89e-06 & 1.62 $\pm$ 7.16e-07 \\
#
#             \multirow{4}{*}{svhn_adaboost4} & \multirow{4}{*}{1.6216061115264893}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.62 $\pm$ 3.12e-05 & 0.48 $\pm$ 1.20e-05 & 1.62 $\pm$ 7.75e-07 \\
#
#             \multirow{4}{*}{svhn_adaboost5} & \multirow{4}{*}{1.6215788125991821}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 1.07e-06 & 0.60 $\pm$ 6.13e-05 & 1.62 $\pm$ 2.20e-06 \\
#
#             \multirow{4}{*}{svhn_adaboost5} & \multirow{4}{*}{1.6215788125991821}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 1.96 $\pm$ 3.91e-05 & 0.56 $\pm$ 1.94e-05 & 1.62 $\pm$ 5.88e-07 \\
#
#             \multirow{4}{*}{svhn_adaboost5} & \multirow{4}{*}{1.6215788125991821}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.78 $\pm$ 4.70e-05 & 0.51 $\pm$ 3.78e-06 & 1.62 $\pm$ 3.97e-07 \\
#
#             \multirow{4}{*}{svhn_adaboost5} & \multirow{4}{*}{1.6215788125991821}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.62 $\pm$ 6.00e-05 & 0.48 $\pm$ 1.73e-05 & 1.62 $\pm$ 2.13e-07 \\
#
#             \multirow{4}{*}{adaboost4} & \multirow{4}{*}{1.4697999954223633}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 1.36e-07 & 0.76 $\pm$ 9.78e-06 & 1.47 $\pm$ 1.57e-08 \\
#
#             \multirow{4}{*}{adaboost4} & \multirow{4}{*}{1.4697999954223633}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 1.99 $\pm$ 3.33e-06 & 0.73 $\pm$ 5.56e-06 & 1.47 $\pm$ 3.72e-08 \\
#
#             \multirow{4}{*}{adaboost4} & \multirow{4}{*}{1.4697999954223633}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.91 $\pm$ 1.06e-05 & 0.71 $\pm$ 2.40e-05 & 1.47 $\pm$ 4.49e-07 \\
#
#             \multirow{4}{*}{adaboost4} & \multirow{4}{*}{1.4697999954223633}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.82 $\pm$ 1.58e-14 & 0.68 $\pm$ 3.95e-15 & 1.47 $\pm$ 0.00e+00 \\
#
#             \multirow{4}{*}{svhn_adaboost2} & \multirow{4}{*}{1.5974992513656616}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 2.15e-06 & 0.62 $\pm$ 6.88e-05 & 1.60 $\pm$ 2.41e-06 \\
#
#             \multirow{4}{*}{svhn_adaboost2} & \multirow{4}{*}{1.5974992513656616}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 1.98 $\pm$ 1.69e-05 & 0.58 $\pm$ 1.78e-05 & 1.60 $\pm$ 8.00e-07 \\
#
#             \multirow{4}{*}{svhn_adaboost2} & \multirow{4}{*}{1.5974992513656616}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.84 $\pm$ 5.49e-05 & 0.54 $\pm$ 1.13e-05 & 1.60 $\pm$ 3.93e-07 \\
#
#             \multirow{4}{*}{svhn_adaboost2} & \multirow{4}{*}{1.5974992513656616}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.70 $\pm$ 3.97e-05 & 0.52 $\pm$ 2.18e-05 & 1.59 $\pm$ 3.00e-07 \\
#
#             \multirow{4}{*}{adaboost1} & \multirow{4}{*}{1.484760046005249}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 1.48e-07 & 0.74 $\pm$ 5.87e-06 & 1.49 $\pm$ 4.09e-08 \\
#
#             \multirow{4}{*}{adaboost1} & \multirow{4}{*}{1.484760046005249}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 1.98 $\pm$ 2.49e-06 & 0.73 $\pm$ 3.90e-06 & 1.49 $\pm$ 1.24e-07 \\
#
#             \multirow{4}{*}{adaboost1} & \multirow{4}{*}{1.484760046005249}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.90 $\pm$ 1.70e-05 & 0.71 $\pm$ 8.86e-06 & 1.48 $\pm$ 7.53e-07 \\
#
#             \multirow{4}{*}{adaboost1} & \multirow{4}{*}{1.484760046005249}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.82 $\pm$ 0.00e+00 & 0.72 $\pm$ 3.95e-15 & 1.48 $\pm$ 0.00e+00 \\
#
#             \multirow{4}{*}{adaboost2} & \multirow{4}{*}{1.4215999841690063}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 6.19e-08 & 0.80 $\pm$ 7.48e-06 & 1.42 $\pm$ 2.59e-08 \\
#
#             \multirow{4}{*}{adaboost2} & \multirow{4}{*}{1.4215999841690063}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 1.99 $\pm$ 2.40e-06 & 0.78 $\pm$ 2.98e-06 & 1.42 $\pm$ 1.43e-07 \\
#
#             \multirow{4}{*}{adaboost2} & \multirow{4}{*}{1.4215999841690063}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.92 $\pm$ 5.71e-06 & 0.76 $\pm$ 1.25e-05 & 1.42 $\pm$ 1.65e-07 \\
#
#             \multirow{4}{*}{adaboost2} & \multirow{4}{*}{1.4215999841690063}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.84 $\pm$ 0.00e+00 & 0.73 $\pm$ 3.95e-15 & 1.42 $\pm$ 1.58e-14 \\
#
#             \multirow{4}{*}{svc1} & \multirow{4}{*}{1.3884400129318237}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 4.95e-08 & 0.77 $\pm$ 2.33e-05 & 1.41 $\pm$ 9.06e-09 \\
#
#             \multirow{4}{*}{svc1} & \multirow{4}{*}{1.3884400129318237}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 1.99 $\pm$ 2.21e-06 & 0.75 $\pm$ 8.33e-06 & 1.41 $\pm$ 1.99e-07 \\
#
#             \multirow{4}{*}{svc1} & \multirow{4}{*}{1.3884400129318237}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.92 $\pm$ 8.74e-06 & 0.72 $\pm$ 1.47e-05 & 1.40 $\pm$ 6.16e-07 \\
#
#             \multirow{4}{*}{svc1} & \multirow{4}{*}{1.3884400129318237}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.85 $\pm$ 0.00e+00 & 0.70 $\pm$ 0.00e+00 & 1.40 $\pm$ 0.00e+00 \\
#
#             \multirow{4}{*}{svc2} & \multirow{4}{*}{1.3559199571609497}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 1.99e-08 & 0.79 $\pm$ 1.16e-05 & 1.38 $\pm$ 3.24e-08 \\
#
#             \multirow{4}{*}{svc2} & \multirow{4}{*}{1.3559199571609497}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 1.99 $\pm$ 3.57e-06 & 0.76 $\pm$ 2.31e-06 & 1.38 $\pm$ 1.80e-07 \\
#
#             \multirow{4}{*}{svc2} & \multirow{4}{*}{1.3559199571609497}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.93 $\pm$ 5.55e-06 & 0.74 $\pm$ 1.41e-05 & 1.38 $\pm$ 3.57e-07 \\
#
#             \multirow{4}{*}{svc2} & \multirow{4}{*}{1.3559199571609497}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.86 $\pm$ 0.00e+00 & 0.71 $\pm$ 0.00e+00 & 1.37 $\pm$ 0.00e+00 \\
#
#             \multirow{4}{*}{svhn_svc2} & \multirow{4}{*}{1.3423700332641602}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 4.38e-09 & 0.81 $\pm$ 2.18e-06 & 1.39 $\pm$ 9.06e-07 \\
#
#             \multirow{4}{*}{svhn_svc2} & \multirow{4}{*}{1.3423700332641602}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 4.76e-07 & 0.79 $\pm$ 3.49e-06 & 1.38 $\pm$ 2.25e-07 \\
#
#             \multirow{4}{*}{svhn_svc2} & \multirow{4}{*}{1.3423700332641602}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.96 $\pm$ 2.97e-06 & 0.78 $\pm$ 2.41e-06 & 1.37 $\pm$ 9.29e-08 \\
#
#             \multirow{4}{*}{svhn_svc2} & \multirow{4}{*}{1.3423700332641602}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.91 $\pm$ 7.74e-06 & 0.76 $\pm$ 5.03e-06 & 1.37 $\pm$ 2.75e-07 \\
#
#             \multirow{4}{*}{svhn_svc1} & \multirow{4}{*}{1.377888798713684}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 1.46e-08 & 0.80 $\pm$ 9.28e-06 & 1.41 $\pm$ 9.42e-07 \\
#
#             \multirow{4}{*}{svhn_svc1} & \multirow{4}{*}{1.377888798713684}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 7.29e-07 & 0.78 $\pm$ 3.19e-06 & 1.40 $\pm$ 7.56e-07 \\
#
#             \multirow{4}{*}{svhn_svc1} & \multirow{4}{*}{1.377888798713684}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.96 $\pm$ 5.98e-06 & 0.76 $\pm$ 5.12e-06 & 1.40 $\pm$ 1.76e-07 \\
#
#             \multirow{4}{*}{svhn_svc1} & \multirow{4}{*}{1.377888798713684}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.90 $\pm$ 7.37e-06 & 0.75 $\pm$ 5.06e-06 & 1.39 $\pm$ 1.45e-07 \\
#
#             \multirow{4}{*}{svhn_adaboost1} & \multirow{4}{*}{1.6110132932662964}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 2.52e-07 & 0.62 $\pm$ 1.62e-05 & 1.61 $\pm$ 1.86e-06 \\
#
#             \multirow{4}{*}{svhn_adaboost1} & \multirow{4}{*}{1.6110132932662964}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 1.97 $\pm$ 8.17e-06 & 0.57 $\pm$ 1.87e-05 & 1.61 $\pm$ 1.21e-06 \\
#
#             \multirow{4}{*}{svhn_adaboost1} & \multirow{4}{*}{1.6110132932662964}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.83 $\pm$ 3.68e-05 & 0.53 $\pm$ 1.04e-05 & 1.61 $\pm$ 2.99e-07 \\
#
#             \multirow{4}{*}{svhn_adaboost1} & \multirow{4}{*}{1.6110132932662964}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.68 $\pm$ 4.29e-05 & 0.51 $\pm$ 9.72e-06 & 1.61 $\pm$ 2.52e-07 \\
#
#             \multirow{4}{*}{svhn_adaboost3} & \multirow{4}{*}{1.6215788125991821}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 1.44e-06 & 0.60 $\pm$ 6.28e-05 & 1.62 $\pm$ 2.32e-06 \\
#
#             \multirow{4}{*}{svhn_adaboost3} & \multirow{4}{*}{1.6215788125991821}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 1.96 $\pm$ 2.25e-05 & 0.56 $\pm$ 2.00e-05 & 1.62 $\pm$ 1.11e-06 \\
#
#             \multirow{4}{*}{svhn_adaboost3} & \multirow{4}{*}{1.6215788125991821}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.78 $\pm$ 7.37e-05 & 0.51 $\pm$ 1.48e-05 & 1.62 $\pm$ 5.64e-07 \\
#
#             \multirow{4}{*}{svhn_adaboost3} & \multirow{4}{*}{1.6215788125991821}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.62 $\pm$ 2.07e-05 & 0.48 $\pm$ 1.88e-05 & 1.62 $\pm$ 5.60e-07 \\
#
#             \multirow{4}{*}{svhn_svc4} & \multirow{4}{*}{1.3423700332641602}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 1.68e-08 & 0.81 $\pm$ 3.16e-06 & 1.39 $\pm$ 7.88e-07 \\
#
#             \multirow{4}{*}{svhn_svc4} & \multirow{4}{*}{1.3423700332641602}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 1.91e-07 & 0.79 $\pm$ 5.94e-06 & 1.38 $\pm$ 5.41e-07 \\
#
#             \multirow{4}{*}{svhn_svc4} & \multirow{4}{*}{1.3423700332641602}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.96 $\pm$ 3.77e-06 & 0.77 $\pm$ 3.53e-06 & 1.37 $\pm$ 3.59e-07 \\
#
#             \multirow{4}{*}{svhn_svc4} & \multirow{4}{*}{1.3423700332641602}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.91 $\pm$ 3.03e-06 & 0.76 $\pm$ 9.02e-06 & 1.37 $\pm$ 1.65e-07 \\
#
#             \multirow{4}{*}{svhn_svc5} & \multirow{4}{*}{1.3630642890930176}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 9.18e-09 & 0.80 $\pm$ 4.66e-06 & 1.40 $\pm$ 6.93e-07 \\
#
#             \multirow{4}{*}{svhn_svc5} & \multirow{4}{*}{1.3630642890930176}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 6.51e-07 & 0.79 $\pm$ 5.87e-06 & 1.39 $\pm$ 4.73e-07 \\
#
#             \multirow{4}{*}{svhn_svc5} & \multirow{4}{*}{1.3630642890930176}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.96 $\pm$ 3.90e-06 & 0.77 $\pm$ 3.74e-06 & 1.39 $\pm$ 4.20e-07 \\
#
#             \multirow{4}{*}{svhn_svc5} & \multirow{4}{*}{1.3630642890930176}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.91 $\pm$ 1.09e-05 & 0.76 $\pm$ 7.95e-06 & 1.38 $\pm$ 9.96e-07 \\
#
#             \multirow{4}{*}{svc3} & \multirow{4}{*}{1.34660005569458}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 5.77e-08 & 0.79 $\pm$ 2.19e-05 & 1.38 $\pm$ 2.81e-08 \\
#
#             \multirow{4}{*}{svc3} & \multirow{4}{*}{1.34660005569458}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 1.99 $\pm$ 4.19e-07 & 0.77 $\pm$ 7.65e-06 & 1.38 $\pm$ 8.82e-08 \\
#
#             \multirow{4}{*}{svc3} & \multirow{4}{*}{1.34660005569458}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.93 $\pm$ 1.11e-05 & 0.75 $\pm$ 5.77e-06 & 1.37 $\pm$ 2.19e-07 \\
#
#             \multirow{4}{*}{svc3} & \multirow{4}{*}{1.34660005569458}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.86 $\pm$ 1.58e-14 & 0.72 $\pm$ 0.00e+00 & 1.36 $\pm$ 0.00e+00 \\
#
#             \multirow{4}{*}{adaboost5} & \multirow{4}{*}{1.5058000087738037}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 3.84e-07 & 0.73 $\pm$ 2.79e-06 & 1.50 $\pm$ 3.18e-08 \\
#
#             \multirow{4}{*}{adaboost5} & \multirow{4}{*}{1.5058000087738037}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 1.98 $\pm$ 4.11e-06 & 0.71 $\pm$ 8.55e-06 & 1.50 $\pm$ 1.41e-07 \\
#
#             \multirow{4}{*}{adaboost5} & \multirow{4}{*}{1.5058000087738037}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.88 $\pm$ 4.18e-06 & 0.69 $\pm$ 2.17e-05 & 1.51 $\pm$ 2.49e-07 \\
#
#             \multirow{4}{*}{adaboost5} & \multirow{4}{*}{1.5058000087738037}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.79 $\pm$ 0.00e+00 & 0.65 $\pm$ 3.95e-15 & 1.51 $\pm$ 1.58e-14 \\
#
#             \multirow{4}{*}{adaboost3} & \multirow{4}{*}{1.5404399633407593}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 2.56e-07 & 0.69 $\pm$ 5.83e-06 & 1.54 $\pm$ 9.37e-09 \\
#
#             \multirow{4}{*}{adaboost3} & \multirow{4}{*}{1.5404399633407593}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 1.98 $\pm$ 5.65e-06 & 0.67 $\pm$ 4.07e-06 & 1.54 $\pm$ 6.46e-08 \\
#
#             \multirow{4}{*}{adaboost3} & \multirow{4}{*}{1.5404399633407593}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.89 $\pm$ 1.36e-05 & 0.66 $\pm$ 2.20e-05 & 1.54 $\pm$ 2.50e-07 \\
#
#             \multirow{4}{*}{adaboost3} & \multirow{4}{*}{1.5404399633407593}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.79 $\pm$ 0.00e+00 & 0.67 $\pm$ 0.00e+00 & 1.54 $\pm$ 0.00e+00 \\
#
#             \multirow{4}{*}{svhn_svc3} & \multirow{4}{*}{1.3206110000610352}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 1.45e-08 & 0.82 $\pm$ 1.57e-06 & 1.37 $\pm$ 1.28e-06 \\
#
#             \multirow{4}{*}{svhn_svc3} & \multirow{4}{*}{1.3206110000610352}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 4.24e-07 & 0.80 $\pm$ 6.30e-06 & 1.37 $\pm$ 4.11e-07 \\
#
#             \multirow{4}{*}{svhn_svc3} & \multirow{4}{*}{1.3206110000610352}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.97 $\pm$ 1.14e-06 & 0.79 $\pm$ 4.25e-06 & 1.36 $\pm$ 6.87e-07 \\
#
#             \multirow{4}{*}{svhn_svc3} & \multirow{4}{*}{1.3206110000610352}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.92 $\pm$ 6.38e-06 & 0.78 $\pm$ 6.47e-06 & 1.35 $\pm$ 5.21e-08 \\
#
#             \multirow{4}{*}{svc4} & \multirow{4}{*}{1.3559199571609497}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 3.48e-08 & 0.79 $\pm$ 8.88e-06 & 1.38 $\pm$ 4.71e-08 \\
#
#             \multirow{4}{*}{svc4} & \multirow{4}{*}{1.3559199571609497}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 1.99 $\pm$ 1.39e-06 & 0.76 $\pm$ 4.16e-06 & 1.38 $\pm$ 1.13e-07 \\
#
#             \multirow{4}{*}{svc4} & \multirow{4}{*}{1.3559199571609497}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.93 $\pm$ 1.32e-05 & 0.74 $\pm$ 1.31e-05 & 1.38 $\pm$ 1.76e-07 \\
#
#             \multirow{4}{*}{svc4} & \multirow{4}{*}{1.3559199571609497}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.86 $\pm$ 0.00e+00 & 0.71 $\pm$ 0.00e+00 & 1.37 $\pm$ 0.00e+00 \\
#
#             \multirow{4}{*}{svc5} & \multirow{4}{*}{1.3569200038909912}
#                     & 100 & 2.00 $\pm$ 0.00e+00 & 2.00 $\pm$ 1.28e-07 & 0.79 $\pm$ 5.11e-06 & 1.38 $\pm$ 3.26e-08 \\
#
#             \multirow{4}{*}{svc5} & \multirow{4}{*}{1.3569200038909912}
#                     & 200 & 2.00 $\pm$ 0.00e+00 & 1.99 $\pm$ 6.29e-07 & 0.76 $\pm$ 4.90e-06 & 1.38 $\pm$ 1.16e-07 \\
#
#             \multirow{4}{*}{svc5} & \multirow{4}{*}{1.3569200038909912}
#                     & 300 & 2.00 $\pm$ 0.00e+00 & 1.92 $\pm$ 5.64e-06 & 0.74 $\pm$ 1.16e-05 & 1.38 $\pm$ 2.15e-07 \\
#
#             \multirow{4}{*}{svc5} & \multirow{4}{*}{1.3569200038909912}
#                     & 400 & 2.00 $\pm$ 0.00e+00 & 1.86 $\pm$ 0.00e+00 & 0.71 $\pm$ 1.60e-10 & 1.37 $\pm$ 0.00e+00 \\
#
#     \hline
#     \end{tabular}
#     \caption{Results}
#     \label{tab:results}
#     \end{table}

# %%
import os
import numpy as np

def convert_to_float(text):
    mean_str, variance_str = text.split('+-')
    mean = float(mean_str)
    variance = float(variance_str)
    return mean, variance

def extract_data_from_file(filepath):
    with open(filepath, 'r') as file:
        data = file.readlines()
    
    train_loss = data[0].strip().split(' ')[-1]
    rob = eval(data[1].strip().split(' ', 1)[1])
    local_rob = eval(data[2].strip().split(' ', 1)[1])
    localsen = eval(data[3].strip().split(' ', 1)[1])
    localavg = eval(data[4].strip().split(' ', 1)[1])
    
    return train_loss, rob, local_rob, localsen, localavg
num_clusters =  [100, 1000, 5000, 10000]

def generate_latex_table(data_dict):
    latex_table = f"""
    \\begin{{table}}[tp]
    \\tiny
    \\centering
    \\caption{{Estimates for the true errors of different models trained on CIFAR10 dataset, when the size $K$ of the partition $\\Gamma$ varies.}}
    \\begin{{tabular}}{{|c|c|c|c|c|c|c|}}
    \\hline
    \\multirow{{2}}{{*}}{{\\textbf{{Model}}}} & \\multirow{{2}}{{*}}{{\\textbf{{Valid Acc}}}} & \\multirow{{2}}{{*}}{{\\textbf{{K}}}} & \\multirow{{2}}{{*}}{{\\textbf{{Rob}}}} & \\multirow{{2}}{{*}}{{\\textbf{{LocalRob}}}} & \\multirow{{2}}{{*}}{{\\textbf{{LocalSen}}}} & \\multirow{{2}}{{*}}{{\\textbf{{LocalAvg}}}} \\\\
    & & & & & &\\\\
    \\hline \\hline
    """
    
    for model, data in data_dict.items():
        for i in range(4):
            rob_mean, rob_var = convert_to_float(data['rob'][i])
            rob_mean = rob_mean /2 + float(data['train_loss']) / 2
            rob_var /= 2
            local_rob_mean, local_rob_var = convert_to_float(data['local_rob'][i])
            local_rob_mean = local_rob_mean / 2 + float(data['train_loss']) / 2
            local_rob_var /= 2
            localsen_mean, localsen_var = convert_to_float(data['localsen'][i])
            localsen_mean = localsen_mean / 2 + float(data['train_loss']) / 2
            localsen_var /= 2
            localavg_mean, localavg_var = convert_to_float(data['localavg'][i])
            localavg_mean = localavg_mean / 2
            localavg_var /= 2
            if i == 0:
                latex_table += f"""
                \\multirow{{4}}{{*}}{{{model}}} & \\multirow{{4}}{{*}}{{$\\text{{{data['train_loss']}}}$}}  
                        & {num_clusters[i]} & {rob_mean:.2f} $\\pm$ {rob_var:.2e} & {local_rob_mean:.2f} $\\pm$ {local_rob_var:.2e} & {localsen_mean:.2f} $\\pm$ {localsen_var:.2e} & {localavg_mean:.2f} $\\pm$ {localavg_var:.2e} \\\\
                """
            else:
                latex_table += f"""
                &  & {num_clusters[i]} & {rob_mean:.2f} $\\pm$ {rob_var:.2e} & {local_rob_mean:.2f} $\\pm$ {local_rob_var:.2e} & {localsen_mean:.2f} $\\pm$ {localsen_var:.2e} & {localavg_mean:.2f} $\\pm$ {localavg_var:.2e} \\\\
                """

    latex_table += """
    \\hline
    \\end{tabular}
    \\caption{Results}
    \\label{tab:results}
    \\end{table}
    """
    
    return latex_table

# Directory containing the files
directory = '/home/leo/Code/generalization_lipschitz/'

# Dictionary to store the extracted data
data_dict = {}

# %%
for filename in os.listdir(directory):
    if filename.endswith('.txt'):
        model_name = filename.split('.')[0].replace('_', '\\_')
        filepath = os.path.join(directory, filename)
        train_loss, rob, local_rob, localsen, localavg = extract_data_from_file(filepath)
        data_dict[model_name] = {
            'train_loss': train_loss,
            'rob': rob,
            'local_rob': local_rob,
            'localsen': localsen,
            'localavg': localavg
        }

# %%
import collections

data_dict = collections.OrderedDict(sorted(data_dict.items()))

# %%
# Generate the LaTeX table
latex_table = generate_latex_table(data_dict)
print(latex_table)
# Out:
#     \begin{table}[tp]
#     \tiny
#     \centering
#     \caption{Estimates for the true errors of different models trained on CIFAR10 dataset, when the size $K$ of the partition $\Gamma$ varies.}
#     \begin{tabular}{|c|c|c|c|c|c|c|}
#     \hline
#     \multirow{2}{*}{\textbf{Model}} & \multirow{2}{*}{\textbf{Valid Acc}} & \multirow{2}{*}{\textbf{K}} & \multirow{2}{*}{\textbf{Rob}} & \multirow{2}{*}{\textbf{LocalRob}} & \multirow{2}{*}{\textbf{LocalSen}} & \multirow{2}{*}{\textbf{LocalAvg}} \\
#     & & & & & &\\
#     \hline \hline
#
#                 \multirow{4}{*}{adaboost1} & \multirow{4}{*}{$\text{1.484760046005249}$}
#                         & 100 & 1.74 $\pm$ 0.00e+00 & 1.74 $\pm$ 7.40e-08 & 1.11 $\pm$ 2.94e-06 & 0.74 $\pm$ 2.05e-08 \\
#
#                 &  & 1000 & 1.74 $\pm$ 0.00e+00 & 1.73 $\pm$ 1.24e-06 & 1.11 $\pm$ 1.95e-06 & 0.74 $\pm$ 6.18e-08 \\
#
#                 &  & 5000 & 1.74 $\pm$ 0.00e+00 & 1.69 $\pm$ 8.50e-06 & 1.10 $\pm$ 4.43e-06 & 0.74 $\pm$ 3.76e-07 \\
#
#                 &  & 10000 & 1.74 $\pm$ 0.00e+00 & 1.65 $\pm$ 0.00e+00 & 1.10 $\pm$ 1.97e-15 & 0.74 $\pm$ 0.00e+00 \\
#
#                 \multirow{4}{*}{adaboost2} & \multirow{4}{*}{$\text{1.4215999841690063}$}
#                         & 100 & 1.71 $\pm$ 0.00e+00 & 1.71 $\pm$ 3.09e-08 & 1.11 $\pm$ 3.74e-06 & 0.71 $\pm$ 1.30e-08 \\
#
#                 &  & 1000 & 1.71 $\pm$ 0.00e+00 & 1.70 $\pm$ 1.20e-06 & 1.10 $\pm$ 1.49e-06 & 0.71 $\pm$ 7.15e-08 \\
#
#                 &  & 5000 & 1.71 $\pm$ 0.00e+00 & 1.67 $\pm$ 2.85e-06 & 1.09 $\pm$ 6.26e-06 & 0.71 $\pm$ 8.25e-08 \\
#
#                 &  & 10000 & 1.71 $\pm$ 0.00e+00 & 1.63 $\pm$ 0.00e+00 & 1.08 $\pm$ 1.97e-15 & 0.71 $\pm$ 7.89e-15 \\
#
#                 \multirow{4}{*}{adaboost3} & \multirow{4}{*}{$\text{1.5404399633407593}$}
#                         & 100 & 1.77 $\pm$ 0.00e+00 & 1.77 $\pm$ 1.28e-07 & 1.12 $\pm$ 2.92e-06 & 0.77 $\pm$ 4.69e-09 \\
#
#                 &  & 1000 & 1.77 $\pm$ 0.00e+00 & 1.76 $\pm$ 2.82e-06 & 1.11 $\pm$ 2.04e-06 & 0.77 $\pm$ 3.23e-08 \\
#
#                 &  & 5000 & 1.77 $\pm$ 0.00e+00 & 1.72 $\pm$ 6.82e-06 & 1.10 $\pm$ 1.10e-05 & 0.77 $\pm$ 1.25e-07 \\
#
#                 &  & 10000 & 1.77 $\pm$ 0.00e+00 & 1.66 $\pm$ 0.00e+00 & 1.11 $\pm$ 0.00e+00 & 0.77 $\pm$ 0.00e+00 \\
#
#                 \multirow{4}{*}{adaboost4} & \multirow{4}{*}{$\text{1.4697999954223633}$}
#                         & 100 & 1.73 $\pm$ 0.00e+00 & 1.73 $\pm$ 6.78e-08 & 1.11 $\pm$ 4.89e-06 & 0.73 $\pm$ 7.84e-09 \\
#
#                 &  & 1000 & 1.73 $\pm$ 0.00e+00 & 1.73 $\pm$ 1.66e-06 & 1.10 $\pm$ 2.78e-06 & 0.74 $\pm$ 1.86e-08 \\
#
#                 &  & 5000 & 1.73 $\pm$ 0.00e+00 & 1.69 $\pm$ 5.30e-06 & 1.09 $\pm$ 1.20e-05 & 0.74 $\pm$ 2.24e-07 \\
#
#                 &  & 10000 & 1.73 $\pm$ 0.00e+00 & 1.64 $\pm$ 7.89e-15 & 1.08 $\pm$ 1.97e-15 & 0.74 $\pm$ 0.00e+00 \\
#
#                 \multirow{4}{*}{adaboost5} & \multirow{4}{*}{$\text{1.5058000087738037}$}
#                         & 100 & 1.75 $\pm$ 0.00e+00 & 1.75 $\pm$ 1.92e-07 & 1.12 $\pm$ 1.40e-06 & 0.75 $\pm$ 1.59e-08 \\
#
#                 &  & 1000 & 1.75 $\pm$ 0.00e+00 & 1.74 $\pm$ 2.05e-06 & 1.11 $\pm$ 4.27e-06 & 0.75 $\pm$ 7.04e-08 \\
#
#                 &  & 5000 & 1.75 $\pm$ 0.00e+00 & 1.70 $\pm$ 2.09e-06 & 1.10 $\pm$ 1.09e-05 & 0.75 $\pm$ 1.24e-07 \\
#
#                 &  & 10000 & 1.75 $\pm$ 0.00e+00 & 1.65 $\pm$ 0.00e+00 & 1.08 $\pm$ 1.97e-15 & 0.75 $\pm$ 7.89e-15 \\
#
#                 \multirow{4}{*}{svc1} & \multirow{4}{*}{$\text{1.3884400129318237}$}
#                         & 100 & 1.69 $\pm$ 0.00e+00 & 1.69 $\pm$ 2.47e-08 & 1.08 $\pm$ 1.16e-05 & 0.70 $\pm$ 4.53e-09 \\
#
#                 &  & 1000 & 1.69 $\pm$ 0.00e+00 & 1.69 $\pm$ 1.10e-06 & 1.07 $\pm$ 4.16e-06 & 0.70 $\pm$ 9.96e-08 \\
#
#                 &  & 5000 & 1.69 $\pm$ 0.00e+00 & 1.65 $\pm$ 4.37e-06 & 1.05 $\pm$ 7.33e-06 & 0.70 $\pm$ 3.08e-07 \\
#
#                 &  & 10000 & 1.69 $\pm$ 0.00e+00 & 1.62 $\pm$ 0.00e+00 & 1.04 $\pm$ 0.00e+00 & 0.70 $\pm$ 0.00e+00 \\
#
#                 \multirow{4}{*}{svc2} & \multirow{4}{*}{$\text{1.3559199571609497}$}
#                         & 100 & 1.68 $\pm$ 0.00e+00 & 1.68 $\pm$ 9.95e-09 & 1.07 $\pm$ 5.81e-06 & 0.69 $\pm$ 1.62e-08 \\
#
#                 &  & 1000 & 1.68 $\pm$ 0.00e+00 & 1.67 $\pm$ 1.78e-06 & 1.06 $\pm$ 1.15e-06 & 0.69 $\pm$ 9.01e-08 \\
#
#                 &  & 5000 & 1.68 $\pm$ 0.00e+00 & 1.64 $\pm$ 2.78e-06 & 1.05 $\pm$ 7.06e-06 & 0.69 $\pm$ 1.78e-07 \\
#
#                 &  & 10000 & 1.68 $\pm$ 0.00e+00 & 1.61 $\pm$ 0.00e+00 & 1.03 $\pm$ 0.00e+00 & 0.68 $\pm$ 0.00e+00 \\
#
#                 \multirow{4}{*}{svc3} & \multirow{4}{*}{$\text{1.34660005569458}$}
#                         & 100 & 1.67 $\pm$ 0.00e+00 & 1.67 $\pm$ 2.88e-08 & 1.07 $\pm$ 1.10e-05 & 0.69 $\pm$ 1.41e-08 \\
#
#                 &  & 1000 & 1.67 $\pm$ 0.00e+00 & 1.67 $\pm$ 2.09e-07 & 1.06 $\pm$ 3.82e-06 & 0.69 $\pm$ 4.41e-08 \\
#
#                 &  & 5000 & 1.67 $\pm$ 0.00e+00 & 1.64 $\pm$ 5.54e-06 & 1.05 $\pm$ 2.88e-06 & 0.68 $\pm$ 1.10e-07 \\
#
#                 &  & 10000 & 1.67 $\pm$ 0.00e+00 & 1.60 $\pm$ 7.89e-15 & 1.04 $\pm$ 0.00e+00 & 0.68 $\pm$ 0.00e+00 \\
#
#                 \multirow{4}{*}{svc4} & \multirow{4}{*}{$\text{1.3559199571609497}$}
#                         & 100 & 1.68 $\pm$ 0.00e+00 & 1.68 $\pm$ 1.74e-08 & 1.07 $\pm$ 4.44e-06 & 0.69 $\pm$ 2.35e-08 \\
#
#                 &  & 1000 & 1.68 $\pm$ 0.00e+00 & 1.67 $\pm$ 6.94e-07 & 1.06 $\pm$ 2.08e-06 & 0.69 $\pm$ 5.67e-08 \\
#
#                 &  & 5000 & 1.68 $\pm$ 0.00e+00 & 1.64 $\pm$ 6.59e-06 & 1.05 $\pm$ 6.55e-06 & 0.69 $\pm$ 8.82e-08 \\
#
#                 &  & 10000 & 1.68 $\pm$ 0.00e+00 & 1.61 $\pm$ 0.00e+00 & 1.03 $\pm$ 0.00e+00 & 0.68 $\pm$ 0.00e+00 \\
#
#                 \multirow{4}{*}{svc5} & \multirow{4}{*}{$\text{1.3569200038909912}$}
#                         & 100 & 1.68 $\pm$ 0.00e+00 & 1.68 $\pm$ 6.40e-08 & 1.07 $\pm$ 2.56e-06 & 0.69 $\pm$ 1.63e-08 \\
#
#                 &  & 1000 & 1.68 $\pm$ 0.00e+00 & 1.67 $\pm$ 3.15e-07 & 1.06 $\pm$ 2.45e-06 & 0.69 $\pm$ 5.78e-08 \\
#
#                 &  & 5000 & 1.68 $\pm$ 0.00e+00 & 1.64 $\pm$ 2.82e-06 & 1.05 $\pm$ 5.82e-06 & 0.69 $\pm$ 1.08e-07 \\
#
#                 &  & 10000 & 1.68 $\pm$ 0.00e+00 & 1.61 $\pm$ 0.00e+00 & 1.04 $\pm$ 8.02e-11 & 0.68 $\pm$ 0.00e+00 \\
#
#                 \multirow{4}{*}{svhn\_adaboost1} & \multirow{4}{*}{$\text{1.6110132932662964}$}
#                         & 100 & 1.81 $\pm$ 0.00e+00 & 1.81 $\pm$ 1.26e-07 & 1.11 $\pm$ 8.10e-06 & 0.80 $\pm$ 9.32e-07 \\
#
#                 &  & 1000 & 1.81 $\pm$ 0.00e+00 & 1.79 $\pm$ 4.09e-06 & 1.09 $\pm$ 9.33e-06 & 0.80 $\pm$ 6.07e-07 \\
#
#                 &  & 5000 & 1.81 $\pm$ 0.00e+00 & 1.72 $\pm$ 1.84e-05 & 1.07 $\pm$ 5.22e-06 & 0.80 $\pm$ 1.49e-07 \\
#
#                 &  & 10000 & 1.81 $\pm$ 0.00e+00 & 1.64 $\pm$ 2.14e-05 & 1.06 $\pm$ 4.86e-06 & 0.80 $\pm$ 1.26e-07 \\
#
#                 \multirow{4}{*}{svhn\_adaboost2} & \multirow{4}{*}{$\text{1.5974992513656616}$}
#                         & 100 & 1.80 $\pm$ 0.00e+00 & 1.80 $\pm$ 1.07e-06 & 1.11 $\pm$ 3.44e-05 & 0.80 $\pm$ 1.21e-06 \\
#
#                 &  & 1000 & 1.80 $\pm$ 0.00e+00 & 1.79 $\pm$ 8.45e-06 & 1.09 $\pm$ 8.88e-06 & 0.80 $\pm$ 4.00e-07 \\
#
#                 &  & 5000 & 1.80 $\pm$ 0.00e+00 & 1.72 $\pm$ 2.75e-05 & 1.07 $\pm$ 5.66e-06 & 0.80 $\pm$ 1.97e-07 \\
#
#                 &  & 10000 & 1.80 $\pm$ 0.00e+00 & 1.65 $\pm$ 1.98e-05 & 1.06 $\pm$ 1.09e-05 & 0.80 $\pm$ 1.50e-07 \\
#
#                 \multirow{4}{*}{svhn\_adaboost3} & \multirow{4}{*}{$\text{1.6215788125991821}$}
#                         & 100 & 1.81 $\pm$ 0.00e+00 & 1.81 $\pm$ 7.19e-07 & 1.11 $\pm$ 3.14e-05 & 0.81 $\pm$ 1.16e-06 \\
#
#                 &  & 1000 & 1.81 $\pm$ 0.00e+00 & 1.79 $\pm$ 1.12e-05 & 1.09 $\pm$ 1.00e-05 & 0.81 $\pm$ 5.54e-07 \\
#
#                 &  & 5000 & 1.81 $\pm$ 0.00e+00 & 1.70 $\pm$ 3.69e-05 & 1.06 $\pm$ 7.38e-06 & 0.81 $\pm$ 2.82e-07 \\
#
#                 &  & 10000 & 1.81 $\pm$ 0.00e+00 & 1.62 $\pm$ 1.03e-05 & 1.05 $\pm$ 9.41e-06 & 0.81 $\pm$ 2.80e-07 \\
#
#                 \multirow{4}{*}{svhn\_adaboost4} & \multirow{4}{*}{$\text{1.6216061115264893}$}
#                         & 100 & 1.81 $\pm$ 0.00e+00 & 1.81 $\pm$ 6.33e-07 & 1.11 $\pm$ 2.39e-05 & 0.81 $\pm$ 1.11e-06 \\
#
#                 &  & 1000 & 1.81 $\pm$ 0.00e+00 & 1.79 $\pm$ 1.84e-05 & 1.09 $\pm$ 2.12e-05 & 0.81 $\pm$ 5.56e-07 \\
#
#                 &  & 5000 & 1.81 $\pm$ 0.00e+00 & 1.70 $\pm$ 8.42e-05 & 1.07 $\pm$ 2.45e-06 & 0.81 $\pm$ 3.58e-07 \\
#
#                 &  & 10000 & 1.81 $\pm$ 0.00e+00 & 1.62 $\pm$ 1.56e-05 & 1.05 $\pm$ 6.01e-06 & 0.81 $\pm$ 3.88e-07 \\
#
#                 \multirow{4}{*}{svhn\_adaboost5} & \multirow{4}{*}{$\text{1.6215788125991821}$}
#                         & 100 & 1.81 $\pm$ 0.00e+00 & 1.81 $\pm$ 5.35e-07 & 1.11 $\pm$ 3.07e-05 & 0.81 $\pm$ 1.10e-06 \\
#
#                 &  & 1000 & 1.81 $\pm$ 0.00e+00 & 1.79 $\pm$ 1.95e-05 & 1.09 $\pm$ 9.70e-06 & 0.81 $\pm$ 2.94e-07 \\
#
#                 &  & 5000 & 1.81 $\pm$ 0.00e+00 & 1.70 $\pm$ 2.35e-05 & 1.07 $\pm$ 1.89e-06 & 0.81 $\pm$ 1.98e-07 \\
#
#                 &  & 10000 & 1.81 $\pm$ 0.00e+00 & 1.62 $\pm$ 3.00e-05 & 1.05 $\pm$ 8.64e-06 & 0.81 $\pm$ 1.06e-07 \\
#
#                 \multirow{4}{*}{svhn\_svc1} & \multirow{4}{*}{$\text{1.377888798713684}$}
#                         & 100 & 1.69 $\pm$ 0.00e+00 & 1.69 $\pm$ 7.32e-09 & 1.09 $\pm$ 4.64e-06 & 0.70 $\pm$ 4.71e-07 \\
#
#                 &  & 1000 & 1.69 $\pm$ 0.00e+00 & 1.69 $\pm$ 3.64e-07 & 1.08 $\pm$ 1.60e-06 & 0.70 $\pm$ 3.78e-07 \\
#
#                 &  & 5000 & 1.69 $\pm$ 0.00e+00 & 1.67 $\pm$ 2.99e-06 & 1.07 $\pm$ 2.56e-06 & 0.70 $\pm$ 8.82e-08 \\
#
#                 &  & 10000 & 1.69 $\pm$ 0.00e+00 & 1.64 $\pm$ 3.68e-06 & 1.06 $\pm$ 2.53e-06 & 0.70 $\pm$ 7.24e-08 \\
#
#                 \multirow{4}{*}{svhn\_svc2} & \multirow{4}{*}{$\text{1.3423700332641602}$}
#                         & 100 & 1.67 $\pm$ 0.00e+00 & 1.67 $\pm$ 2.19e-09 & 1.08 $\pm$ 1.09e-06 & 0.69 $\pm$ 4.53e-07 \\
#
#                 &  & 1000 & 1.67 $\pm$ 0.00e+00 & 1.67 $\pm$ 2.38e-07 & 1.07 $\pm$ 1.74e-06 & 0.69 $\pm$ 1.12e-07 \\
#
#                 &  & 5000 & 1.67 $\pm$ 0.00e+00 & 1.65 $\pm$ 1.49e-06 & 1.06 $\pm$ 1.21e-06 & 0.69 $\pm$ 4.65e-08 \\
#
#                 &  & 10000 & 1.67 $\pm$ 0.00e+00 & 1.63 $\pm$ 3.87e-06 & 1.05 $\pm$ 2.51e-06 & 0.68 $\pm$ 1.38e-07 \\
#
#                 \multirow{4}{*}{svhn\_svc3} & \multirow{4}{*}{$\text{1.3206110000610352}$}
#                         & 100 & 1.66 $\pm$ 0.00e+00 & 1.66 $\pm$ 7.24e-09 & 1.07 $\pm$ 7.85e-07 & 0.69 $\pm$ 6.38e-07 \\
#
#                 &  & 1000 & 1.66 $\pm$ 0.00e+00 & 1.66 $\pm$ 2.12e-07 & 1.06 $\pm$ 3.15e-06 & 0.68 $\pm$ 2.06e-07 \\
#
#                 &  & 5000 & 1.66 $\pm$ 0.00e+00 & 1.64 $\pm$ 5.68e-07 & 1.05 $\pm$ 2.12e-06 & 0.68 $\pm$ 3.44e-07 \\
#
#                 &  & 10000 & 1.66 $\pm$ 0.00e+00 & 1.62 $\pm$ 3.19e-06 & 1.05 $\pm$ 3.23e-06 & 0.68 $\pm$ 2.60e-08 \\
#
#                 \multirow{4}{*}{svhn\_svc4} & \multirow{4}{*}{$\text{1.3423700332641602}$}
#                         & 100 & 1.67 $\pm$ 0.00e+00 & 1.67 $\pm$ 8.40e-09 & 1.08 $\pm$ 1.58e-06 & 0.69 $\pm$ 3.94e-07 \\
#
#                 &  & 1000 & 1.67 $\pm$ 0.00e+00 & 1.67 $\pm$ 9.57e-08 & 1.07 $\pm$ 2.97e-06 & 0.69 $\pm$ 2.70e-07 \\
#
#                 &  & 5000 & 1.67 $\pm$ 0.00e+00 & 1.65 $\pm$ 1.89e-06 & 1.06 $\pm$ 1.77e-06 & 0.69 $\pm$ 1.80e-07 \\
#
#                 &  & 10000 & 1.67 $\pm$ 0.00e+00 & 1.63 $\pm$ 1.52e-06 & 1.05 $\pm$ 4.51e-06 & 0.68 $\pm$ 8.24e-08 \\
#
#                 \multirow{4}{*}{svhn\_svc5} & \multirow{4}{*}{$\text{1.3630642890930176}$}
#                         & 100 & 1.68 $\pm$ 0.00e+00 & 1.68 $\pm$ 4.59e-09 & 1.08 $\pm$ 2.33e-06 & 0.70 $\pm$ 3.47e-07 \\
#
#                 &  & 1000 & 1.68 $\pm$ 0.00e+00 & 1.68 $\pm$ 3.25e-07 & 1.08 $\pm$ 2.93e-06 & 0.70 $\pm$ 2.37e-07 \\
#
#                 &  & 5000 & 1.68 $\pm$ 0.00e+00 & 1.66 $\pm$ 1.95e-06 & 1.07 $\pm$ 1.87e-06 & 0.69 $\pm$ 2.10e-07 \\
#
#                 &  & 10000 & 1.68 $\pm$ 0.00e+00 & 1.64 $\pm$ 5.43e-06 & 1.06 $\pm$ 3.97e-06 & 0.69 $\pm$ 4.98e-07 \\
#
#     \hline
#     \end{tabular}
#     \caption{Results}
#     \label{tab:results}
#     \end{table}
